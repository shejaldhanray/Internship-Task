# %% [markdown]
# <a href="https://colab.research.google.com/github/shejaldhanray/Internship-Task/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Image to Pencil Sketch with Python**

# %% [markdown]
# **1. Importing Required libraries**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %% [markdown]
# **2. Loading the Image**

# %%
image=cv2.imread("/content/cat3.jpg")
image = cv2.resize(image,(500,500))
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [214, 203, 199],
#         [214, 203, 199],
#         [215, 204, 200]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [214, 203, 199],
#         [215, 204, 200],
#         [215, 204, 200]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [215, 204, 200],
#         [215, 204, 200],
#         [216, 205, 201]],
#
#        ...,
#
#        [[132, 132, 132],
#         [102, 102, 103],
#         [ 62,  63,  64],
#         ...,
#         [ 80, 110, 167],
#         [ 79, 112, 167],
#         [ 82, 115, 171]],
#
#        [[ 99,  97,  97],
#         [ 39,  37,  38],
#         [  4,   2,   3],
#         ...,
#         [ 63,  95, 146],
#         [ 60,  94, 146],
#         [ 59,  93, 146]],
#
#        [[ 46,  45,  46],
#         [  9,   7,   9],
#         [ 17,  15,  17],
# ...

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# **3. Converting into Gray Scale**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[255, 255, 255, ..., 203, 203, 204],
#        [255, 255, 255, ..., 203, 204, 204],
#        [255, 255, 255, ..., 204, 204, 205],
#        ...,
#        [132, 102,  63, ..., 124, 125, 128],
#        [ 97,  38,   3, ..., 107, 106, 105],
#        [ 45,   8,  16, ..., 100, 103, 101]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# **4. Inverting the image**

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[  0,   0,   0, ...,  52,  52,  51],
#        [  0,   0,   0, ...,  52,  51,  51],
#        [  0,   0,   0, ...,  51,  51,  50],
#        ...,
#        [123, 153, 192, ..., 131, 130, 127],
#        [158, 217, 252, ..., 148, 149, 150],
#        [210, 247, 239, ..., 155, 152, 154]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %% [markdown]
# **5. Smoothing the image**

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[  0,   0,   0, ...,  52,  52,  52],
#        [  0,   0,   0, ...,  52,  52,  51],
#        [  0,   0,   0, ...,  52,  52,  51],
#        ...,
#        [175, 176, 179, ..., 148, 149, 149],
#        [180, 182, 185, ..., 147, 148, 148],
#        [182, 184, 187, ..., 147, 148, 148]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# **6. Inverting the Image to get the Pencil Sketch**

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# **7. Comparing the Original Image with Pencil Sketch**

# %%
display(Image.fromarray(img_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F3A02C3CAF0>

# %%
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F3A02C175B0>
